# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Exercice 0.1

# %%
# %run 1
# Out:
# countries: ['Portugal', 'Spain']

# %% [markdown]
# # Exercice 0.2

# %%
# %run 2
# Out:
# 1
# 2
# 3

# %% [markdown]
# # Exercice 0.3

# %%
# %run 3
# Out:
# Invalid hour: it should be between 0 and 24
# Invalid hour: it should be between 0 and 24
# Good morning !
# Good afternoon !
# Good evening !

# %% [markdown]
# # Exercice 0.4

# %%
# %run 4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Desktop/repos/lxmls-2020/lxmls-toolkit/exercices/day_0/4.py in <module>
#       9                 print('Good evening !')
#      10
# ---> 11 greet(50)
#      12 greet(-5)
#      13 greet(8)
#
# ~/Desktop/repos/lxmls-2020/lxmls-toolkit/exercices/day_0/4.py in greet(hour)
#       1 def greet(hour):
#       2         if hour < 0 or hour > 24:
# ----> 3                 raise ValueError('Invalid hour: it should be between 0 and 24')
#       4         elif hour < 12:
#       5                 print('Good morning !')
#
# ValueError: Invalid hour: it should be between 0 and 24

# %% [markdown]
# # Exercice 0.5

# %%
# %run 5

# %% [markdown]
# # Exercice 0.6

# %%
# %run 6

np.ptp?
# Out:
# 49.5
# 49.5
# 1.9999608263946371

# %% [markdown]
# # Exercice 0.7

# %%
# %run 7
# Out:
# integral: 0.3328335

# %% [markdown]
# # Exercice 0.8

# %%
# %run 8
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# (3, 2)
# float64
# int64
# [[2 3]
#  [3 4]]

# %% [markdown]
# # Exercice 0.9

# %%
# %run 9
# Out:
# [[2 3]
#  [3 4]]
# [[5. 5.]
#  [7. 7.]]
# [[5 5]
#  [7 7]]

# %% [markdown]
# # Exercice 0.10

# %%
# %run 10
# Out:
# data: [[70.5 61.7]
#  [68.5 61.7]
#  [65.5 61.7]
#  ...
#  [69.5 73.7]
#  [69.5 73.7]
#  [69.5 73.7]]
# global mean height: 68.19832974137931
# global std height: 2.185000397276442
# fathers mean height: 68.30818965517241
# fathers std height: 1.7863701392420732
# sons mean height: 68.08846982758622
# sons std height: 2.516584351160004

# %% [markdown]
# # Exercice 0.11

# %%
# %run 11

# %% [markdown]
# # Exercice 0.12

# %%
# %run 12
# Out:
# change in function values too small, leaving

# %% [markdown]
# # Exercice 0.13

# %%
# %run 13
# Out:
# data shape: (928, 2)
# w: [ 0.5 50. ]
# y.shape: (928,)
# x.shape: (2, 928)
# w.shape: (2,)
# derivative: [2145.09490302   31.47209052]
# res: [[ 0.5        50.        ]
#  [ 0.07098102 49.99370558]
#  [ 0.43879991 49.99909818]
#  [ 0.12345095 49.99447093]
#  [ 0.393815   49.99843418]
#  [ 0.16201881 49.99503238]
#  [ 0.36074901 49.997945  ]
#  [ 0.190368   49.99544396]
#  [ 0.33644399 49.99758431]
#  [ 0.211206   49.99574537]
#  [ 0.31857867 49.99731807]
#  [ 0.22652292 49.9959658 ]
#  [ 0.30544685 49.99712125]
#  [ 0.23778158 49.99612672]
#  [ 0.29579436 49.99697547]
#  [ 0.24605724 49.99624388]
#  [ 0.28869935 49.9968672 ]
#  [ 0.25214026 49.99632889]
#  [ 0.2834842  49.99678649]
#  [ 0.25661157 49.99639025]
#  [ 0.27965084 49.99672606]
#  [ 0.25989821 49.99643424]
#  [ 0.27683316 49.99668051]
#  [ 0.26231406 49.99646546]
#  [ 0.27476205 49.99664592]
#  [ 0.26408984 49.99648729]
#  [ 0.2732397  49.99661938]
#  [ 0.26539514 49.99650222]
#  [ 0.27212072 49.99659876]
# ...

# %% [markdown]
# # Exercice 0.14

# %%
# %run 14
# Out:
# 290.892
